# %%
path = "/Users/lrburack/Documents/CERN/Leptoquark/lq_object_selection/models/NN_4mu_5jet/M300-300/model.pkl"

import pickle
with open(path, "rb") as f:
    model = pickle.load(f)

# %%
print(model.trained_model["clf"].out_activation_)
# Out:
# logistic
